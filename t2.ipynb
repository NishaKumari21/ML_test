# %%
#  Dataset  - Employee Data  
# Create a dataset and then perform the below problems on Dataset 
# (Add the github link After solving the problem) 
# 20. Plot a bar chart to visualize the number of employees in each department using Matplotlib.

# 21. Filter out employees with a salary greater than 60,000 using Pandas.

# 22.  Create a line graph for the salary trend by department.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('department_salary.csv')
df
# Out:
#       Name  Age Department  Salary
# 0    Alice   25         HR   50000
# 1      Bob   30         IT   70000
# 2  Charlie   35      Sales   45000
# 3    David   28         HR   52000
# 4      Eve   40         IT   80000

# %%
x=df['Name']
y=df['Department']
plt.bar(x,y)
plt.show()

# %%
#Q2. Filter out employees with a salary greater than 60,000 using Pandas.
filtered= df[df['Salary'] > 60000]
print("fitered_db:",filtered)
# Out:
# fitered_db:   Name  Age Department  Salary
# 1  Bob   30         IT   70000
# 4  Eve   40         IT   80000

# %%
# Q3.  Create a line graph for the salary trend by department.
x=df["Salary"]
y=df["Department"]
# Plot the line graph
plt.plot(x, y, color="r", label="Line Graph")
plt.show()
